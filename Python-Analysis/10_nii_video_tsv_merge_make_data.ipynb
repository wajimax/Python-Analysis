# %%
#交差検証
# %matplotlib inline
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import defaultdict
import codecs

# %%
with codecs.open("./Output/video_tsv_merge.tsv",mode ="r", errors="ignore") as file:
#    video_tsv_merge_data = pd.read_table(file, delimiter='\t', engine='python',error_bad_lines=False, nrows=20,header=None)
    video_tsv_merge_data = pd.read_table(file, delimiter='\t', engine='python',error_bad_lines=False ,header=None)

# %%
#データセットの表示
video_tsv_merge_data
# Out:
#                   0       1      2     3   \
# 0             sm8896   38882   1292   435
# 1             sm5800  429015   2464  2757
# 2             sm8917    3953     63    13
# 3             sm4786    7636    164    19
# 4             sm5017    1274     13     0
# 5             sm1552   10007    349    27
# 6             sm2467    9521    418    50
# 7             sm7747   31762     92    12
# 8             sm7864  362704   7167  5678
# 9             sm4375  141676   1678  2463
# 10            sm8740   16523    235   464
# 11             sm999  367366   1102  1038
# 12            sm6049  323885  26669  1043
# 13            sm5545  117858   2963  1445
# 14            sm6832   20541    287   140
# 15            sm7198    5633    116     8
# 16            sm1024   17458    270   199
# 17            sm3754    6968   1667    13
# 18            sm1435    5640     79    27
# 19            sm1846   26588    340   234
# 20            sm6010    6205    158     5
# ...

# %%
#ヘッダーを設定
video_tsv_merge_data = video_tsv_merge_data.iloc[:,0:11]
video_tsv_merge_data.columns = ['video_id', 'watch_num', 'comment_num','mylist_num','title','category','upload_time','file_type','length','size_high','size_low']
video_tsv_merge_data
# Out:
#             video_id  watch_num  comment_num  mylist_num  \
# 0             sm8896      38882         1292         435
# 1             sm5800     429015         2464        2757
# 2             sm8917       3953           63          13
# 3             sm4786       7636          164          19
# 4             sm5017       1274           13           0
# 5             sm1552      10007          349          27
# 6             sm2467       9521          418          50
# 7             sm7747      31762           92          12
# 8             sm7864     362704         7167        5678
# 9             sm4375     141676         1678        2463
# 10            sm8740      16523          235         464
# 11             sm999     367366         1102        1038
# 12            sm6049     323885        26669        1043
# 13            sm5545     117858         2963        1445
# 14            sm6832      20541          287         140
# ...

# %%
video_tsv_merge_data.shape
# Out:
# (16703001, 11)

# %%
#数値の基本統計量を算出
video_tsv_merge_data.describe()
# Out:
#           watch_num   comment_num    mylist_num   upload_time        length  \
# count  1.670300e+07  1.670300e+07  1.670300e+07  1.670300e+07  1.670300e+07
# mean   5.881200e+03  2.279580e+02  6.114715e+01  1.371889e+09  7.239232e+02
# std    4.725444e+04  1.615608e+04  2.586976e+03  9.624238e+07  8.100906e+02
# min    0.000000e+00  0.000000e+00  0.000000e+00  3.240000e+04  0.000000e+00
# 25%    1.360000e+02  2.000000e+00  1.000000e+00  1.293883e+09  2.060000e+02
# 50%    5.090000e+02  1.200000e+01  2.000000e+00  1.370885e+09  4.610000e+02
# 75%    2.059000e+03  5.700000e+01  1.200000e+01  1.453559e+09  1.068000e+03
# max    2.797349e+07  4.295413e+07  1.001139e+07  1.915010e+09  6.553500e+04
#
#           size_high      size_low
# count  1.670300e+07  1.670300e+07
# mean   5.132999e+07  2.672473e+07
# std    4.981779e+07  2.850898e+07
# min    0.000000e+00  0.000000e+00
# 25%    1.231566e+07  5.304406e+06
# 50%    3.998235e+07  1.630308e+07
# 75%    9.350840e+07  3.895186e+07
# ...

# %%
#video_tsv_merge_data.describe().to_csv('./Output/video_tsv_merge_data_describe_int.tsv', index=False, sep='\t')

# %%
#文字列で出力して、unique性を評価
video_tsv_merge_data = video_tsv_merge_data.astype(str)
video_tsv_merge_data.describe()
# Out:
#           video_id watch_num comment_num mylist_num     title  category  \
# count     16703001  16703001    16703001   16703001  16703001  16703001
# unique    16682350    218609       35135      17247  16353639        39
# top     sm18162938        23           0          1      test       ゲーム
# freq            50     40404     2719371    4301304      7639   6872919
#
#        upload_time file_type    length size_high  size_low
# count     16703001  16703001  16703001  16703001  16703001
# unique    14512913         3     13430  13998516  13027547
# top     1340722800       mp4        90         1         0
# freq          4297  14087648     69436    506043   1449058

# %%
#ファイル保存
video_tsv_merge_data.to_csv('./Output/video_tsv_merge_data.tsv', index=False, sep='\t')
video_tsv_merge_data.describe().to_csv('./Output/video_tsv_merge_data_describe.tsv', index=False, sep='\t')
